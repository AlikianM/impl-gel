# %%
'''
cipapi_download_html_reports

Polling GeL CIPAP and downloading all GMC relevant html reports.
These are archived and relevant tables possibly scraped as needed.

Created 07-12-2018 by Graham Rose
'''

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Using CipApi and Authentication modules, and passing query string to grab specific LDP cases only. Specify if download of htmls is needed - if true checks of html report already exists on local system and skips these.

# %%
from poll_cipapi import CipApi
from cipauth import Authenticate

#ir = CipApi(sample_type='cancer', search='imperial', download_html=False)
ir = CipApi(sample_type='cancer', search='imperial', download_html=True)
# Out:
# Initialising PollCipApi
# Searching  imperial  LDP within WL GMC for all  cancer cases...
# Cases for  cancer found:  108
# Striping out all non relevant cases, ie. cases not sent to gmc...
# Relevant cases for cancer kept:  106
# Setting up folder structure...
# Pulling html for case... 16435-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1529058376.7/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1529058373.39/download-file/
# Pulling html for case... 17417-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1529671255.73/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1529671254.31/download-file/
# Pulling html for case... 17453-1
# Downloading the report... 1029463948_220000190_LP3000822-DNA_D12_LP3000819-DNA_D08.v1_8.supplementary.html
# Downloading the report... 1029463948_220000190_LP3000822-DNA_D12_LP3000819-DNA_D08.v1_8.html
# Pulling html for case... 19453-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211556.47/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211554.8/download-file/
# Pulling html for case... 19457-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211726.18/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211724.93/download-file/
# Pulling html for case... 19460-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211844.05/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211842.44/download-file/
# Pulling html for case... 19461-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211875.03/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531211874.35/download-file/
# Pulling html for case... 19470-1
# Downloading the report... 1022863027_220000077_LP3000200-DNA_D04_LP3000178-DNA_G07.v1_8.supplementary.html
# Downloading the report... 1022863027_220000077_LP3000200-DNA_D04_LP3000178-DNA_G07.v1_8.html
# Pulling html for case... 19472-1
# Downloading the report... 1022862893_220000032_LP3000206-DNA_G01_LP3000115-DNA_D09.v1_8.html
# Downloading the report... 1022862893_220000032_LP3000206-DNA_G01_LP3000115-DNA_D09.v1_8.supplementary.html
# Pulling html for case... 19479-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531212872.4/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531212871.59/download-file/
# Pulling html for case... 19483-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213061.91/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213060.35/download-file/
# Pulling html for case... 19486-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213123.8/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213122.68/download-file/
# Pulling html for case... 19487-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213143.6/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213142.93/download-file/
# Pulling html for case... 19490-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213199.04/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213197.88/download-file/
# Pulling html for case... 19494-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213407.62/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213406.29/download-file/
# Pulling html for case... 19496-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213448.28/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531213447.33/download-file/
# Pulling html for case... 19517-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531231454.24/download-file/
# Pulling html for case... 19527-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531231594.45/download-file/
# Pulling html for case... 19559-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531232266.01/download-file/
# Pulling html for case... 19565-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531232396.04/download-file/
# Pulling html for case... 19574-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531232536.36/download-file/
# Pulling html for case... 19607-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531233179.32/download-file/
# Pulling html for case... 19610-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531233244.42/download-file/
# Pulling html for case... 19617-1
# Downloading the report... 1021207381_220000108_LP3000280-DNA_D02_LP3000279-DNA_E11.v1_8.html
# Pulling html for case... 19628-1
# Downloading the report... 1022867399_220000011_LP3000070-DNA_D03_LP3000067-DNA_H07.v1_8.html
# Downloading the report... 1022867399_220000011_LP3000070-DNA_D03_LP3000067-DNA_H07.v1_8.supplementary.html
# Pulling html for case... 19632-1
# Downloading the report... 1022862935_220000052_LP3000210-DNA_A02_LP3000205-DNA_D06.v1_8.html
# Downloading the report... 1022862935_220000052_LP3000210-DNA_A02_LP3000205-DNA_D06.v1_8.supplementary.html
# Pulling html for case... 19637-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531233761.44/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531233760.22/download-file/
# Pulling html for case... 19642-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531233820.91/download-file/
# Pulling html for case... 19649-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531233975.93/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531233973.91/download-file/
# Pulling html for case... 19653-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234029.16/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234028.24/download-file/
# Pulling html for case... 19661-1
# Downloading the report... 1022862836_220000036_LP3000140-DNA_H03_LP3000114-DNA_D01.v1_8.html
# Pulling html for case... 19663-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234274.53/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234273.56/download-file/
# Pulling html for case... 19671-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234399.92/download-file/
# Pulling html for case... 19682-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234564.14/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234562.46/download-file/
# Pulling html for case... 19694-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234772.55/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234771.86/download-file/
# Pulling html for case... 19700-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234931.44/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531234930.37/download-file/
# Pulling html for case... 19703-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531235000.09/download-file/
# Pulling html for case... 19709-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531235110.64/download-file/
# Pulling html for case... 19716-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531235287.98/download-file/
# Pulling html for case... 19719-1
# Downloading the report... 1021207406_220000009_LP3000140-DNA_D02_LP3000115-DNA_E11.v1_8.html
# Pulling html for case... 19720-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531235381.06/download-file/
# Pulling html for case... 19721-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531235397.65/download-file/
# Pulling html for case... 19730-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531235549.46/download-file/
# Pulling html for case... 19738-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531235671.78/download-file/
# Pulling html for case... 19767-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236297.54/download-file/
# Pulling html for case... 19771-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236374.31/download-file/
# Pulling html for case... 19776-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236523.86/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236523.2/download-file/
# Pulling html for case... 19781-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236579.34/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236578.67/download-file/
# Pulling html for case... 19786-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236650.52/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236649.03/download-file/
# Pulling html for case... 19787-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531236677.66/download-file/
# Pulling html for case... 20346-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531830054.8/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1531830052.82/download-file/
# Pulling html for case... 21408-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532077558.17/download-file/
# Pulling html for case... 21425-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532078551.72/download-file/
# Pulling html for case... 21476-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532080566.6/download-file/
# Pulling html for case... 22053-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532365577.37/download-file/
# Pulling html for case... 22250-1
# Downloading the report... 1022867388_220000021_LP3000070-DNA_D06_LP3000067-DNA_D12.v1_8.html
# Downloading the report... 1022867388_220000021_LP3000070-DNA_D06_LP3000067-DNA_D12.v1_8.supplementary.html
# Pulling html for case... 22299-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532425109.8/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532425108.91/download-file/
# Pulling html for case... 22315-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532426421.49/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532426420.43/download-file/
# Pulling html for case... 22316-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532426444.44/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532426442.84/download-file/
# Pulling html for case... 22331-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532427046.62/download-file/
# Pulling html for case... 22349-1
# Downloading the report... 1027359891_220000145_LP3000714-DNA_D05_LP3000713-DNA_D10.v1_8.html
# Pulling html for case... 22699-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532956285.33/download-file/
# Pulling html for case... 22722-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532957553.91/download-file/
# Pulling html for case... 22724-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532957643.93/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1532957643.35/download-file/
# Pulling html for case... 22884-1
# Downloading the report... 1032880564_215001368_LP3000905-DNA_H09_LP3000867-DNA_D06.v1_8.supplementary.html
# Downloading the report... 1032880564_215001368_LP3000905-DNA_H09_LP3000867-DNA_D06.v1_8.html
# Pulling html for case... 22924-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1533121844.98/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1533121842.54/download-file/
# Pulling html for case... 22931-1
# Downloading the report... 1022862831_220000064_LP3000140-DNA_C02_LP3000115-DNA_D05.v1_8.html
# Pulling html for case... 23089-1
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1533311388.59/download-file/
# File already exits locally, skipping download... https://cipapi.genomicsengland.nhs.uk/api/2/file/1533311387.59/download-file/
# Pulling html for case... 23933-1
# Downloading the report... 1019103534_215002312_LP3001072-DNA_G07_LP3001064-DNA_D01.v1_8.html
# Downloading the report... 1019103534_215002312_LP3001072-DNA_G07_LP3001064-DNA_D01.v1_8.supplementary.html
# Pulling html for case... 24021-1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-2f6bcfe3d57b> in <module>()
#       3
#       4 #ir = CipApi(sample_type='cancer', search='imperial', download_html=False)
# ----> 5 ir = CipApi(sample_type='cancer', search='imperial', download_html=True)
#
# ~/bioinf/gmc_lab_variants_db/poll_cipapi.py in __init__(self, sample_type, search, download_html)
#      48
#      49         if download_html == True and self.sample_type == "cancer":
# ---> 50             self.download_cancer_html_reports()
#      51         else:
#      52             pass
#
# ~/bioinf/gmc_lab_variants_db/poll_cipapi.py in download_cancer_html_reports(self)
#     174                     if os.path.exists(file_output_path) == False:
#     175                         download = self.return_response_as_stream(
# --> 176                             result_report_url)
#     177
#     178                         with open(file_output_path, 'wb') as f:
#
# ~/bioinf/gmc_lab_variants_db/poll_cipapi.py in return_response_as_stream(self, result_report_url)
#     197
#     198         response = requests.get(
# --> 199             url=result_report_url, headers=auth.get_authenticated_header(), stream = True)
#     200
#     201         return response
#
# ~/bioinf/gmc_lab_variants_db/cipauth.py in get_authenticated_header(self)
#      30             json=dict(
#      31                 username=os.getenv("CIP_API_USERNAME"),
# ---> 32                 password=os.getenv("CIP_API_PASSWORD"),
#      33             ),
#      34         )
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     496             hooks=hooks,
#     497         )
# --> 498         prep = self.prepare_request(req)
#     499
#     500         proxies = proxies or {}
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in prepare_request(self, request)
#     439             auth=merge_setting(auth, self.auth),
#     440             cookies=merged_cookies,
# --> 441             hooks=merge_hooks(request.hooks, self.hooks),
#     442         )
#     443         return p
#
# /anaconda3/lib/python3.6/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     307
#     308         self.prepare_method(method)
# --> 309         self.prepare_url(url, params)
#     310         self.prepare_headers(headers)
#     311         self.prepare_cookies(cookies)
#
# /anaconda3/lib/python3.6/site-packages/requests/models.py in prepare_url(self, url, params)
#     373         # Support for unicode domain names and paths.
#     374         try:
# --> 375             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     376         except LocationParseError as e:
#     377             raise InvalidURL(*e.args)
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/url.py in parse_url(url)
#     170     # Find the earliest Authority Terminator
#     171     # (http://tools.ietf.org/html/rfc3986#section-3.2)
# --> 172     url, path_, delim = split_first(url, ['/', '?', '#'])
#     173
#     174     if delim:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/url.py in split_first(s, delims)
#     115     min_idx = None
#     116     min_delim = None
# --> 117     for d in delims:
#     118         idx = s.find(d)
#     119         if idx < 0:
#
# KeyboardInterrupt:
